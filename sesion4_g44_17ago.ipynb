# %% [markdown]
# <a href="https://colab.research.google.com/github/AbbySnt/EstadisticaAplicada_1990002/blob/main/sesion4_g44_17ago.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Estadistica aplicada
#
# sesion 4 - 17ago
#
# yessica abigail santiago hernandez 1990002
#
# Gpo44

# %% [markdown]
# importacion de librerias a utilizar

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# Importar los datos a utilizar

# %%
calificaciones = pd.read_csv('https://raw.githubusercontent.com/jimmyzac/Estadistica-Aplicada-FCFM-UANL/main/bases_datos/Calificaciones.csv')

# %%
#saber el tamaño de la base de datos
calificaciones.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 28 entries, 0 to 27
# Data columns (total 4 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Id                 28 non-null     int64
#  1   Nombre             28 non-null     object
#  2   Apellido           28 non-null     object
#  3   Calficación Final  28 non-null     int64
# dtypes: int64(2), object(2)
# memory usage: 1.0+ KB

# %%
calificaciones.shape #(filas,columnas) es par saber el numero de filas y columnas
# Out:
# (28, 4)

# %%
calificaciones.head() #codigo para postrar las primeras 5 observaciones
# Out:
#    Id   Nombre   Apellido  Calficación Final
# 0   1  ANTONIO     GARCIA                 73
# 1   2   MANUEL  FERNANDEZ                 19
# 2   3     JOSE   GONZALEZ                 38
# 3   4    DAVID      PEREZ                 14
# 4   5     JUAN      LOPEZ                 99

# %%
calificaciones.head(3) #codigo para mostrar las primeras n observaciones
# Out:
#    Id   Nombre   Apellido  Calficación Final
# 0   1  ANTONIO     GARCIA                 73
# 1   2   MANUEL  FERNANDEZ                 19
# 2   3     JOSE   GONZALEZ                 38

# %%
calificaciones.tail()#codigo para ver las ultimas observaciones
# Out:
#     Id       Nombre   Apellido  Calficación Final
# 23  24         LUIS  DOMINGUEZ                 12
# 24  25      ALBERTO      ORTIZ                 99
# 25  26  JUAN CARLOS     IBAÑEZ                 43
# 26  27       ALVARO    RAMIREZ                 40
# 27  28       ADRIAN       SAEZ                  7

# %%
calificaciones.tail(6)#codigo para ver las ultimas n observaciones
# Out:
#     Id       Nombre   Apellido  Calficación Final
# 22  23        JORGE      RAMOS                 76
# 23  24         LUIS  DOMINGUEZ                 12
# 24  25      ALBERTO      ORTIZ                 99
# 25  26  JUAN CARLOS     IBAÑEZ                 43
# 26  27       ALVARO    RAMIREZ                 40
# 27  28       ADRIAN       SAEZ                  7

# %%
#eliminar una columna
calificaciones = calificaciones[['Nombre','Apellido','Calficación Final']]

# %%
#renombrar el nombre de una columna
calificaciones = calificaciones.rename(columns={'Calficación Final':'CalFinal'})

# %%
calificaciones.head()
# Out:
#     Nombre   Apellido  CalFinal
# 0  ANTONIO     GARCIA        73
# 1   MANUEL  FERNANDEZ        19
# 2     JOSE   GONZALEZ        38
# 3    DAVID      PEREZ        14
# 4     JUAN      LOPEZ        99

# %%
#calcular el promedio
calificaciones['CalFinal'].mean()
# Out:
# 52.0

# %%
#clasificar que alumnos aprobaron
calificaciones['situacion'] = np.where(calificaciones['CalFinal']>=70,'Aprobado','Reprobado')

# %%
calificaciones.head()
# Out:
#     Nombre   Apellido  CalFinal  situacion
# 0  ANTONIO     GARCIA        73   Aprobado
# 1   MANUEL  FERNANDEZ        19  Reprobado
# 2     JOSE   GONZALEZ        38  Reprobado
# 3    DAVID      PEREZ        14  Reprobado
# 4     JUAN      LOPEZ        99   Aprobado

# %%
#contar cuandot alumnos estan aprobados y reprobados
calificaciones.groupby('situacion')['CalFinal'].count()
# Out:
# situacion
# Aprobado     10
# Reprobado    18
# Name: CalFinal, dtype: int64

# %%
#promedio de aprobados y reprobados
calificaciones.groupby('situacion')['CalFinal'].mean().round(1)
# Out:
# situacion
# Aprobado     90.1
# Reprobado    30.8
# Name: CalFinal, dtype: float64

# %%
#contarlos y sacar el promedio al mismo tiempo
## agg sirve para decirle a python que se la va a indicar varias cosas
calificaciones.groupby('situacion')['CalFinal'].agg(['mean','count','std']).round(1)
# Out:
#            mean  count   std
# situacion
# Aprobado   90.1     10  10.0
# Reprobado  30.8     18  21.6

# %%
aprobados = calificaciones.query('situacion == "Aprobado" ')
reprobados = calificaciones.query('situacion == "Reprobado" ')

# %%
aprobados
# Out:
#           Nombre Apellido  CalFinal situacion
# 0        ANTONIO   GARCIA        73  Aprobado
# 4           JUAN    LOPEZ        99  Aprobado
# 7      JOSE LUIS    GOMEZ        89  Aprobado
# 10         JESUS   ALONSO        94  Aprobado
# 12        MIGUEL     DIAZ        85  Aprobado
# 14        RAFAEL  ALVAREZ        86  Aprobado
# 15  MIGUEL ANGEL   MORENO       100  Aprobado
# 18         ANGEL      GIL       100  Aprobado
# 22         JORGE    RAMOS        76  Aprobado
# 24       ALBERTO    ORTIZ        99  Aprobado

# %%
reprobados
# Out:
#               Nombre   Apellido  CalFinal  situacion
# 1             MANUEL  FERNANDEZ        19  Reprobado
# 2               JOSE   GONZALEZ        38  Reprobado
# 3              DAVID      PEREZ        14  Reprobado
# 5       JOSE ANTONIO  RODRIGUEZ        66  Reprobado
# 6             JAVIER    SANCHEZ        46  Reprobado
# 8   FRANCISCO JAVIER    JIMENEZ        10  Reprobado
# 9             CARLOS       RUIZ        62  Reprobado
# 11         ALEJANDRO  HERNANDEZ        17  Reprobado
# 13       JOSE MANUEL  GUTIERREZ        34  Reprobado
# 16             PEDRO      MUÑOZ         1  Reprobado
# 17             PABLO     BLANCO        64  Reprobado
# 19            SERGIO    AGUIRRE         2  Reprobado
# 20        JOSE MARIA       DIEZ        29  Reprobado
# 21          FERNANDO    SALAZAR        51  Reprobado
# 23              LUIS  DOMINGUEZ        12  Reprobado
# 25       JUAN CARLOS     IBAÑEZ        43  Reprobado
# 26            ALVARO    RAMIREZ        40  Reprobado
# ...

# %% [markdown]
# ## Matplotlib mathematical plot library
# grafiacador de python

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
 #matplotlib es para que siempre se haga un grafica se muestre

# %%
personas = [1,2,3,4]
edades = [25,27,21,30]

# %%
#graficar
plt.bar(personas,edades)
plt.show() #forma correcta  forma incorrecta: es poner un ; al final del plt

# %%
#darle los ejes y titulo y color
plt.bar(personas,edades, color = 'yellow')
plt.xlabel('personas')
plt.ylabel('edades (años)')
plt.title('Edades de 4 desconocidos')
plt.show()

# %%
#darle los ejes y titulo y color para cada barra
plt.bar(personas,edades, color = ['yellow','green','red','orange'])
plt.xlabel('personas')
plt.ylabel('edades (años)')
plt.title('Edades de 4 desconocidos')
plt.show()
